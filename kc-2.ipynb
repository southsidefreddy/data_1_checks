# %% [markdown]
# #  **Summary**
#
#  Dataset with information about dog breeds

# %%
#import libraries

import pandas as pd
import numpy as np
import seaborn as sns

# %%
#read in data

dogs_df = pd.read_csv("assets/dog_breeds.csv")
print(dogs_df)
# Out:
#                      Breed Country of Origin                     Fur Color  \
# 0       Labrador Retriever            Canada      Yellow, Black, Chocolate
# 1          German Shepherd           Germany                    Black, Tan
# 2                  Bulldog           England                    White, Red
# 3                   Poodle            France  White, Black, Brown, Apricot
# 4                   Beagle           England        White, Tan, Red, Lemon
# ..                     ...               ...                           ...
# 112  Catahoula Leopard Dog     United States                  Merle, Black
# 113         Cocker Spaniel           England                  Black, Brown
# 114    Miniature Shiba Inu             Japan                   Red, Sesame
# 115       Belgian Tervuren           Belgium                          Fawn
# 116          Pharaoh Hound             Malta                           Red
#
#     Height (in) Color of Eyes Longevity (yrs)  \
# ...

# %%
#list columns

dogs_df.columns
# Out:
# Index(['Breed', 'Country of Origin', 'Fur Color', 'Height (in)',
#        'Color of Eyes', 'Longevity (yrs)', 'Character Traits',
#        'Common Health Problems'],
#       dtype='object')

# %%
# get the number of row and columns

dogs_df.shape
# Out:
# (117, 8)

# %%
#list the data types

dogs_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 117 entries, 0 to 116
# Data columns (total 8 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Breed                   117 non-null    object
#  1   Country of Origin       117 non-null    object
#  2   Fur Color               117 non-null    object
#  3   Height (in)             117 non-null    object
#  4   Color of Eyes           117 non-null    object
#  5   Longevity (yrs)         117 non-null    object
#  6   Character Traits        117 non-null    object
#  7   Common Health Problems  117 non-null    object
# dtypes: object(8)
# memory usage: 7.4+ KB

# %%
# get number of missing records

dogs_df.isnull().sum().sort_values(ascending=False)
# Out:
# Breed                     0
# Country of Origin         0
# Fur Color                 0
# Height (in)               0
# Color of Eyes             0
# Longevity (yrs)           0
# Character Traits          0
# Common Health Problems    0
# dtype: int64

# %%
dogs_df
# Out:
#                      Breed Country of Origin                     Fur Color  \
# 0       Labrador Retriever            Canada      Yellow, Black, Chocolate
# 1          German Shepherd           Germany                    Black, Tan
# 2                  Bulldog           England                    White, Red
# 3                   Poodle            France  White, Black, Brown, Apricot
# 4                   Beagle           England        White, Tan, Red, Lemon
# ..                     ...               ...                           ...
# 112  Catahoula Leopard Dog     United States                  Merle, Black
# 113         Cocker Spaniel           England                  Black, Brown
# 114    Miniature Shiba Inu             Japan                   Red, Sesame
# 115       Belgian Tervuren           Belgium                          Fawn
# 116          Pharaoh Hound             Malta                           Red
#
#     Height (in) Color of Eyes Longevity (yrs)  \
# ...

# %%
# display top rows of data

pd.set_option("display.max.columns", None)
dogs_df.head()
# Out:
#                 Breed Country of Origin                     Fur Color  \
# 0  Labrador Retriever            Canada      Yellow, Black, Chocolate
# 1     German Shepherd           Germany                    Black, Tan
# 2             Bulldog           England                    White, Red
# 3              Poodle            France  White, Black, Brown, Apricot
# 4              Beagle           England        White, Tan, Red, Lemon
#
#   Height (in) Color of Eyes Longevity (yrs)  \
# 0       21-24         Brown           10-12
# 1       22-26         Brown            7-10
# 2       12-16         Brown            8-10
# 3       10-15   Brown, Blue           12-15
# 4       13-15         Brown           12-15
#
#                                     Character Traits  \
# 0  Loyal, friendly, intelligent, energetic, good-...
# 1  Loyal, intelligent, protective, confident, tra...
# 2                         Loyal, calm, gentle, brave
# 3  Intelligent, active, affectionate, hypoallergenic
# ...

# %%
# find data type

print(dogs_df.dtypes)
# Out:
# Breed                     object
# Country of Origin         object
# Fur Color                 object
# Height (in)               object
# Color of Eyes             object
# Longevity (yrs)           object
# Character Traits          object
# Common Health Problems    object
# dtype: object

# %%
# create data plot

sns.scatterplot(x=dogs_df['Breed'],
                y=dogs_df['Longevity (yrs)'])
# Out:
# <Axes: xlabel='Breed', ylabel='Longevity (yrs)'>
